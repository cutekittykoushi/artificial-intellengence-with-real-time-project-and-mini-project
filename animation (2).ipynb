# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
 animegirl=os.listdir("C:/Users/Koushika/Downloads/anime girls")

# %%
animegirl
# Out:
# ['01-animegirl.jpg',
#  '02-animegirl.jpg',
#  '03-animegirl.jpg',
#  '04-animegirl.jpg',
#  '05-animegirl.jpg',
#  '06-animegirl.jpg',
#  '07-animegirl.jpg',
#  '08-animegirl.jpg',
#  '09-animegirl.jpg',
#  '10-animegirl.jpg',
#  '11-animegirl.jpg',
#  '12-animegirl.jpg',
#  '13-animegirl.jpg',
#  '14-animegirl.jpg',
#  '15-animegirl.jpg',
#  '16-animegirl.jpg',
#  '17-animegirl.jpg',
#  '18-animegirl.jpg',
#  '19-animegirl.jpg',
#  '20-animegirl.jpg',
#  '21-animegirl.jpg',
#  '22-animegirl.jpg',
#  '23-animegirl.jpg',
#  '24-animegirl.jpg',
#  '25-animegirl.jpg',
#  '26-animegirl.jpg',
#  '27-animegirl.jpg',
#  '28-animegirl.jpg',
#  '29-animegirl.jpg',
#  '30-animegirl.jpg',
#  '31-animegirl.jpg',
#  '32-animegirl.jpg',
#  '33-animegirl.jpg',
#  '34-animegirl.jpg',
#  '35-animegirl.jpg',
#  '36-animegirl.jpg',
#  '37-animegirl.jpg',
#  '38-animegirl.jpg',
#  '39-animegirl.jpg',
#  '40-animegirl.jpg',
#  '41-animegirl.jpg',
#  '42-animegirl.jpg',
#  '43-animegirl.jpg',
# ...

# %%
limit=54
animegirl_images=[None]*limit
j=0
for i in animegirl:
    if(j<limit):
        animegirl_images[j]=imread("C:/Users/Koushika/Downloads/anime girls/"+i)
        j+=1
    else:
        break

# %%
imshow(animegirl_images[26])

# %%
imshow(animegirl_images[40])

# %%
imshow(animegirl_images[33])

# %%
animegirl_images_bw=[None]*limit
j=0
for i in animegirl:
    if(j<limit):
        animegirl_images_bw[j]=rgb2gray(animegirl_images[j])
        j+=1
    else:
        break

# %%
imshow(animegirl_images_bw[1])

# %%
animegirl_images_bw[12].shape
# Out:
# (1080, 1080)

# %%
imshow(animegirl_images_bw[6])

# %%
animegirl_images_bw[6].shape
# Out:
# (592, 474)

# %%
for j in range(54):
    ag=animegirl_images_bw[j]
    animegirl_images_bw[j]=resize(ag,(224,224))

# %%
animegirl_images_bw[1].shape
# Out:
# (224, 224)

# %%
animegirl_images_bw[9].shape
# Out:
# (224, 224)

# %%
animegirl_images_bw[7].shape
# Out:
# (224, 224)

# %%
imshow(animegirl_images_bw[10])

# %%
len_of_images=len(animegirl_images_bw)

# %%
len_of_images
# Out:
# 54

# %%
image_size_animegirl=animegirl_images_bw[1].shape

# %%
image_size_animegirl
# Out:
# (224, 224)

# %%
flatten_size_animegirl=image_size_animegirl[0]*image_size_animegirl[1]

# %%
flatten_size_animegirl
# Out:
# 50176

# %%
for i in range(len_of_images):
    animegirl_images_bw[i]=np.ndarray.flatten(animegirl_images_bw[i]).reshape(flatten_size_animegirl,1)

# %%
animegirl_images_bw=np.dstack(animegirl_images_bw)

# %%
animegirl_images_bw.shape
# Out:
# (50176, 1, 54)

# %%
animegirl_images_bw=np.dstack(animegirl_images_bw)

# %%
animegirl_images_bw
# Out:
# array([[[0.11127721, 0.08407408, 0.07788464, ..., 0.15281278,
#          0.14526022, 0.14429804],
#         [0.0458913 , 0.04851543, 0.04514533, ..., 0.17271755,
#          0.16059445, 0.03051785],
#         [0.67518757, 0.6704111 , 0.66866232, ..., 0.02004193,
#          0.0146159 , 0.01525738],
#         ...,
#         [0.79570549, 0.79570549, 0.79570549, ..., 0.33074957,
#          0.32815103, 0.33280975],
#         [0.80703529, 0.80703529, 0.80703529, ..., 0.08735294,
#          0.08735294, 0.08735294],
#         [0.83671451, 0.83671451, 0.84063608, ..., 0.26783725,
#          0.27175882, 0.27175882]]])

# %%
animegirl_images_bw.shape
# Out:
# (1, 54, 50176)

# %%
animegirl_images_bw=np.rollaxis(animegirl_images_bw,axis=2,start=0)

# %%
animegirl_images_bw.shape
# Out:
# (50176, 1, 54)

# %%
animegirl_images_bw=animegirl_images_bw.reshape(len_of_images,flatten_size_animegirl)

# %%
animegirl_images_bw.shape
# Out:
# (54, 50176)

# %%
animegirl_data=pd.DataFrame(animegirl_images_bw)

# %%
animegirl_data
# Out:
#        0         1         2         3         4         5         6      \
# 0   0.111277  0.045891  0.675188  0.816068  0.305935  0.871787  0.103910
# 1   0.478853  0.474016  0.913566  0.232178  0.919846  0.646030  0.780309
# 2   0.735818  0.315646  0.772847  0.410887  0.935498  0.949287  0.403578
# 3   0.264992  0.441322  0.474714  0.876448  0.600952  0.672299  0.458381
# 4   0.579821  0.647833  0.283408  0.108541  0.540365  0.801342  0.651807
# 5   0.311121  0.808245  0.807035  0.570336  0.785890  0.527248  0.431672
# 6   0.216155  0.816899  0.612709  0.834025  0.579519  0.493427  0.761175
# 7   0.788328  0.539265  0.878610  0.792157  0.740316  0.275904  0.746394
# 8   0.789549  0.368818  0.766066  0.603958  0.316273  0.406453  0.731363
# 9   0.206255  0.479364  0.400218  0.366675  0.622961  0.633348  0.431508
# 10  0.362744  0.161645  0.482131  0.286988  0.584738  0.753526  0.068682
# 11  0.349621  0.448025  0.124077  0.418377  0.165238  0.920647  0.164930
# ...

# %%
animegirl_data['label']='animegirl'

# %%
animegirl_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.111277  0.045891  0.675188  0.816068  0.305935  0.871787  0.103910
# 1   0.478853  0.474016  0.913566  0.232178  0.919846  0.646030  0.780309
# 2   0.735818  0.315646  0.772847  0.410887  0.935498  0.949287  0.403578
# 3   0.264992  0.441322  0.474714  0.876448  0.600952  0.672299  0.458381
# 4   0.579821  0.647833  0.283408  0.108541  0.540365  0.801342  0.651807
# 5   0.311121  0.808245  0.807035  0.570336  0.785890  0.527248  0.431672
# 6   0.216155  0.816899  0.612709  0.834025  0.579519  0.493427  0.761175
# 7   0.788328  0.539265  0.878610  0.792157  0.740316  0.275904  0.746394
# 8   0.789549  0.368818  0.766066  0.603958  0.316273  0.406453  0.731363
# 9   0.206255  0.479364  0.400218  0.366675  0.622961  0.633348  0.431508
# 10  0.362744  0.161645  0.482131  0.286988  0.584738  0.753526  0.068682
# 11  0.349621  0.448025  0.124077  0.418377  0.165238  0.920647  0.164930
# ...

# %%
animation=pd.concat([animegirl_data])

# %%
animation
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.111277  0.045891  0.675188  0.816068  0.305935  0.871787  0.103910
# 1   0.478853  0.474016  0.913566  0.232178  0.919846  0.646030  0.780309
# 2   0.735818  0.315646  0.772847  0.410887  0.935498  0.949287  0.403578
# 3   0.264992  0.441322  0.474714  0.876448  0.600952  0.672299  0.458381
# 4   0.579821  0.647833  0.283408  0.108541  0.540365  0.801342  0.651807
# 5   0.311121  0.808245  0.807035  0.570336  0.785890  0.527248  0.431672
# 6   0.216155  0.816899  0.612709  0.834025  0.579519  0.493427  0.761175
# 7   0.788328  0.539265  0.878610  0.792157  0.740316  0.275904  0.746394
# 8   0.789549  0.368818  0.766066  0.603958  0.316273  0.406453  0.731363
# 9   0.206255  0.479364  0.400218  0.366675  0.622961  0.633348  0.431508
# 10  0.362744  0.161645  0.482131  0.286988  0.584738  0.753526  0.068682
# 11  0.349621  0.448025  0.124077  0.418377  0.165238  0.920647  0.164930
# ...

# %%
animation_data=pd.concat([animation,animegirl_data])

# %%
animation_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.111277  0.045891  0.675188  0.816068  0.305935  0.871787  0.103910
# 1   0.478853  0.474016  0.913566  0.232178  0.919846  0.646030  0.780309
# 2   0.735818  0.315646  0.772847  0.410887  0.935498  0.949287  0.403578
# 3   0.264992  0.441322  0.474714  0.876448  0.600952  0.672299  0.458381
# 4   0.579821  0.647833  0.283408  0.108541  0.540365  0.801342  0.651807
# ..       ...       ...       ...       ...       ...       ...       ...
# 49  0.224834  0.313579  0.706147  0.847352  0.073592  0.321194  0.082991
# 50  0.097839  0.492926  0.206196  0.339039  0.463516  0.119581  0.681115
# 51  0.188311  0.791784  0.610865  0.166061  0.747432  0.431042  0.500655
# 52  0.534135  0.249916  0.730795  0.125268  0.235468  0.100634  0.304253
# 53  0.176986  0.089096  0.908933  0.555928  0.155017  0.346697  0.137758
#
#            7         8         9  ...     50167     50168     50169     50170  \
# ...

# %%
from sklearn.utils import shuffle

# %%
animation_girl=shuffle(animation_data).reset_index()

# %%
animation_girl
# Out:
#      index         0         1         2         3         4         5  \
# 0       15  0.816752  0.051983  0.693523  0.163346  0.403262  0.187807
# 1       12  0.833878  0.042545  0.819320  0.670818  0.909326  0.349928
# 2       10  0.362744  0.161645  0.482131  0.286988  0.584738  0.753526
# 3       51  0.188311  0.791784  0.610865  0.166061  0.747432  0.431042
# 4       13  0.692656  0.818748  0.933526  0.929651  0.412064  0.865044
# ..     ...       ...       ...       ...       ...       ...       ...
# 103     23  0.237734  0.123119  0.267622  0.486856  0.714461  0.660141
# 104     16  0.127597  0.559220  0.159058  0.164959  0.925177  0.093054
# 105     32  0.090369  0.835053  0.304082  0.665467  0.028913  0.046202
# 106      0  0.111277  0.045891  0.675188  0.816068  0.305935  0.871787
# 107      6  0.216155  0.816899  0.612709  0.834025  0.579519  0.493427
#
#             6         7         8  ...     50167     50168     50169  \
# ...

# %%
final_animation_girl=animation_girl.drop(['index'],axis=1)

# %%
final_animation_girl
# Out:
#             0         1         2         3         4         5         6  \
# 0    0